# %%
import os
import re
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %%
fname  = os.path.expandvars("$HOME/Software/HK_Software/WCSimFQTuningTools/Time/tres_trueq_2Dhistogram.root")
# fname  = os.path.expandvars("$LUSTRE/Time/e-/tuning/tres_trueq_2Dhistogram.root")

f  = uproot.open(fname)

print(f.classnames())
# Out:
# {'htimepdf_direct_100.509697;1': 'TH2D', 'htimepdf_indirect_100.509697;1': 'TH2D', 'htimepdf_direct_120.509918;1': 'TH2D', 'htimepdf_indirect_120.509918;1': 'TH2D', 'htimepdf_direct_140.510071;1': 'TH2D', 'htimepdf_indirect_140.510071;1': 'TH2D', 'htimepdf_direct_160.510193;1': 'TH2D', 'htimepdf_indirect_160.510193;1': 'TH2D', 'htimepdf_direct_180.510269;1': 'TH2D', 'htimepdf_indirect_180.510269;1': 'TH2D', 'htimepdf_direct_200.510345;1': 'TH2D', 'htimepdf_indirect_200.510345;1': 'TH2D', 'htimepdf_direct_220.510406;1': 'TH2D', 'htimepdf_indirect_220.510406;1': 'TH2D', 'htimepdf_direct_240.510452;1': 'TH2D', 'htimepdf_indirect_240.510452;1': 'TH2D', 'htimepdf_direct_260.510498;1': 'TH2D', 'htimepdf_indirect_260.510498;1': 'TH2D', 'htimepdf_direct_280.510529;1': 'TH2D', 'htimepdf_indirect_280.510529;1': 'TH2D', 'htimepdf_direct_300.510559;1': 'TH2D', 'htimepdf_indirect_300.510559;1': 'TH2D', 'htimepdf_direct_320.510590;1': 'TH2D', 'htimepdf_indirect_320.510590;1': 'TH2D', 'htimepdf_direct_340.510620;1': 'TH2D', 'htimepdf_indirect_340.510620;1': 'TH2D', 'htimepdf_direct_360.510651;1': 'TH2D', 'htimepdf_indirect_360.510651;1': 'TH2D', 'htimepdf_direct_380.510651;1': 'TH2D', 'htimepdf_indirect_380.510651;1': 'TH2D', 'htimepdf_direct_400.510681;1': 'TH2D', 'htimepdf_indirect_400.510681;1': 'TH2D', 'htimepdf_direct_420.510681;1': 'TH2D', 'htimepdf_indirect_420.510681;1': 'TH2D', 'htimepdf_direct_440.510712;1': 'TH2D', 'htimepdf_indirect_440.510712;1': 'TH2D', 'htimepdf_direct_460.510712;1': 'TH2D', 'htimepdf_indirect_460.510712;1': 'TH2D', 'htimepdf_direct_480.510742;1': 'TH2D', 'htimepdf_indirect_480.510742;1': 'TH2D', 'htimepdf_direct_500.510742;1': 'TH2D', 'htimepdf_indirect_500.510742;1': 'TH2D', 'htimepdf_direct_520.510742;1': 'TH2D', 'htimepdf_indirect_520.510742;1': 'TH2D', 'htimepdf_direct_540.510742;1': 'TH2D', 'htimepdf_indirect_540.510742;1': 'TH2D', 'htimepdf_direct_560.510742;1': 'TH2D', 'htimepdf_indirect_560.510742;1': 'TH2D', 'htimepdf_direct_580.510803;1': 'TH2D', 'htimepdf_indirect_580.510803;1': 'TH2D', 'htimepdf_direct_600.510803;1': 'TH2D', 'htimepdf_indirect_600.510803;1': 'TH2D', 'htimepdf_direct_620.510803;1': 'TH2D', 'htimepdf_indirect_620.510803;1': 'TH2D', 'htimepdf_direct_640.510803;1': 'TH2D', 'htimepdf_indirect_640.510803;1': 'TH2D', 'htimepdf_direct_660.510803;1': 'TH2D', 'htimepdf_indirect_660.510803;1': 'TH2D', 'htimepdf_direct_680.510803;1': 'TH2D', 'htimepdf_indirect_680.510803;1': 'TH2D', 'htimepdf_direct_700.510803;1': 'TH2D', 'htimepdf_indirect_700.510803;1': 'TH2D', 'htimepdf_direct_720.510803;1': 'TH2D', 'htimepdf_indirect_720.510803;1': 'TH2D', 'htimepdf_direct_740.510803;1': 'TH2D', 'htimepdf_indirect_740.510803;1': 'TH2D', 'htimepdf_direct_760.510803;1': 'TH2D', 'htimepdf_indirect_760.510803;1': 'TH2D', 'htimepdf_direct_780.510803;1': 'TH2D', 'htimepdf_indirect_780.510803;1': 'TH2D', 'htimepdf_direct_800.510864;1': 'TH2D', 'htimepdf_indirect_800.510864;1': 'TH2D', 'htimepdf_direct_820.510864;1': 'TH2D', 'htimepdf_indirect_820.510864;1': 'TH2D', 'htimepdf_direct_840.510864;1': 'TH2D', 'htimepdf_indirect_840.510864;1': 'TH2D', 'htimepdf_direct_860.510864;1': 'TH2D', 'htimepdf_indirect_860.510864;1': 'TH2D', 'htimepdf_direct_880.510864;1': 'TH2D', 'htimepdf_indirect_880.510864;1': 'TH2D', 'htimepdf_direct_900.510864;1': 'TH2D', 'htimepdf_indirect_900.510864;1': 'TH2D', 'htimepdf_direct_920.510864;1': 'TH2D', 'htimepdf_indirect_920.510864;1': 'TH2D', 'htimepdf_direct_940.510864;1': 'TH2D', 'htimepdf_indirect_940.510864;1': 'TH2D', 'htimepdf_direct_960.510864;1': 'TH2D', 'htimepdf_indirect_960.510864;1': 'TH2D', 'htimepdf_direct_980.510864;1': 'TH2D', 'htimepdf_indirect_980.510864;1': 'TH2D', 'htimepdf_direct_1000.510864;1': 'TH2D', 'htimepdf_indirect_1000.510864;1': 'TH2D', 'Total;1': 'TGraph', 'PC;1': 'TGraph', 'Conversion;1': 'TGraph'}

# %%
# get simulated momenta
histonames = list(f.classnames().keys())
momenta = []
for name in histonames:
    m = re.match(r"htimepdf_direct_(\d+\.\d+)", name)
    if m: momenta.append(float(m.group(1)))
momenta = np.array(momenta)
momenta.sort()

# %%
# read 2D histogram
p = np.random.choice(momenta)
print(f"Selecting p = {p} (MeV/c)")

try:
    Hdirect  , tresbins, trueqbins = f[f"htimepdf_direct_{p}"]  .to_numpy()
    Hindirect, tresbins, trueqbins = f[f"htimepdf_indirect_{p}"].to_numpy()
except uproot.KeyInFileError:
    Hdirect  , tresbins, trueqbins = f[f"htimepdf_direct_{p}0"].to_numpy()
    Hindirect, tresbins, trueqbins = f[f"htimepdf_indirect_{p}0"].to_numpy()

plt.figure(figsize=[10, 2.5])

plt.subplot(121)
plt.title("Direct")
plt.pcolormesh(tresbins, trueqbins, Hdirect.T)
plt.xlabel(r"residual time ($t$)")
plt.ylabel(r"log10 true charge ($\mu^{dir}$)")
plt.colorbar()

plt.subplot(122)
plt.title("Indirect")
plt.pcolormesh(tresbins, trueqbins, Hindirect.T)
plt.xlabel(r"residual time ($t^{res}$) (ns)")
plt.ylabel(r"log10 true charge ($\mu^{indirect}$)")
plt.colorbar()

plt.tight_layout()
# Out:
# Selecting p = 660.510803 (MeV/c)

# %%
ps, ntotal = f["Total"].values()
ps, npc    = f["PC"]   .values()

efficiency = 1 - npc/ntotal

plt.figure(figsize=[10, 3])

plt.subplot(121)
plt.scatter(ps, efficiency, s=10, color="k")
plt.xlabel("momentum (MeV/c)")
plt.ylabel("No-PC efficiency")

plt.subplot(122)
plt.scatter(ps, ntotal-npc, s=10, color="k")
plt.xlabel("momentum (MeV/c)")
plt.ylabel("No-PC statistics")

plt.tight_layout()

# %% [markdown]
# ### Indirect Time PDF

# %%
from scipy.optimize import curve_fit

# function to fit
def indirect_timepdf(t, delta, sig, gamma):
    out = np.zeros(len(t))

    dt = t - delta
    A = 1./(np.sqrt(np.pi/2.)*sig + 2*gamma)

    sel = dt<0
    out[sel]  = A*np.exp(-dt[sel]**2/(2.*sig**2))
    out[~sel] = A*(dt[~sel]/gamma + 1.)*np.exp(-dt[~sel]/gamma)
    
    return out

# %%
# get data (tres distribution for each momentum)
timepdf = dict()
for p in momenta:
    try:
        Hindirect, tresbins, trueqbins = f[f"htimepdf_indirect_{p}"].to_numpy()
    except uproot.KeyInFileError:
        Hindirect, tresbins, trueqbins = f[f"htimepdf_indirect_{p}0"].to_numpy()

    h    = Hindirect.sum(axis=1)
    norm = np.sum(h*(tresbins[1:]-tresbins[:-1]))
    timepdf[p] = h/norm

# %%
p = momenta[0]

plt.figure(figsize=[5, 3])

for p in momenta[::10]:
    h = timepdf[p]
    plt.stairs(h, tresbins, label=f"p = {int(p)} MeV/c")

plt.xlabel(r"residual time ($t^{res}$) (ns)")
plt.legend()
plt.tight_layout()

# %%
# merge momentum distributions
pdf = np.zeros(len(tresbins)-1)
for p in momenta: pdf += timepdf[p]
norm = np.sum(pdf*(tresbins[1:]-tresbins[:-1]))
pdf = pdf/norm

tress = (tresbins[1:] + tresbins[:-1])/2.
params, covariance = curve_fit(indirect_timepdf, tress, pdf, bounds=([0, -np.inf, -np.inf], [np.inf, np.inf, np.inf]))
params, covariance = curve_fit(indirect_timepdf, tress, pdf)

# %%
fig = plt.figure(figsize=[5, 3])
ax = fig.add_subplot(111)

ax.stairs(pdf, tresbins, color="k", label=f"p = {int(p)} MeV/c")

ts   = np.linspace(tress[0], tress[-1], 100)
pdf_ = indirect_timepdf(ts, *params)
ax.plot(ts, pdf_, color="r")

text = fr"$\delta = {round(params[0], 2)}$" + "\n" \
     + fr"$\sigma = {round(params[1], 2)}$" + "\n" \
     + fr"$\gamma = {round(params[2], 2)}$"


ax.text(0.7, 0.5, text, transform=ax.transAxes)

ax.set_xlabel(r"residual time ($t^{res}$) (ns)")
fig.tight_layout()

# %% [markdown]
# ### Conversion factor charge-nphotons-momentum

# %%
nphotons, charge = f["Conversion"].values()

pars = np.polyfit(nphotons, charge, 1)
print("Conversion factor (photons/charge)", (1/pars[0]))

fig = plt.figure(figsize=[5, 3])
ax = fig.add_subplot(111)

plt.scatter(nphotons, charge, s=2)

pol = np.poly1d(pars)
plt.plot(nphotons, pol(nphotons), color="red")

plt.xlabel("Nphotons")
plt.ylabel("Charge")

plt.tight_layout()
# Out:
# Conversion factor (photons/charge) 5.11074989037585
